# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Asus.csv')
X = dataset.iloc[:, :-1].values
y =  dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
dataset
# Out:
#     Category       Series        ModelName                 Colour&Chassis  \
# 0    Premium   TUF Gaming   FX505DT-AL118T                      GUN METAL
# 1    Premium   TUF Gaming   FX705DT-AU092T                  BLACK PLASTIC
# 2    Premium   TUF Gaming   FX705DT-AU016T                      GUN METAL
# 3   Platinum  ROG-Strix G    G531GT-BQ002T               BLACK W+LIGHTBAR
# 4   Platinum  ROG-Strix G    G531GT-AL264T  1F-G Glacier Blue W+ Lightbar
# ..       ...          ...              ...                            ...
# 88   Premium      TUF A15  FA566IH-HN150TS                  Fortress Gray
# 89   Premium      TUF A15   FA566II-HN230T                  Fortress Gray
# 90   Premium      TUF A15   FA566II-HN231T                  Fortress Gray
# 91   Premium      TUF A15   FA566IU-HN244T                  Fortress Gray
# 92   Premium      TUF A15   FA566IU-HN246T                  Fortress Gray
#
#                                           Description Warrenty     MRP
# 0   R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   77990
# 1   R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   80990
# 2   R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   94990
# 3   i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   97990
# 4   i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15...       1Y   98990
# ..                                                ...      ...     ...
# 88  R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+256G SSD+ ...       1Y   96990
# 89  R5-4600H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD...       1Y   98990
# 90  R7-4800H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD...       1Y  110990
# 91  R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T HDD+512G ...       1Y  120990
# 92  R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T SSD+ 15.6...       1Y  128990
#
# [93 rows x 7 columns]

# %%
print(X)
# Out:
# [['Premium' 'TUF Gaming' 'FX505DT-AL118T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DT-AU092T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DT-AU016T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G531GT-BQ002T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G531GT-AL264T'
#   '1F-G Glacier Blue W+ Lightbar'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G Glacier Blue W+ Lightbar"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DY-BQ024T' 'BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GM-BQ344T' '1C Black'
#   "I5-8300H +GTX1060-6GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard- Red +WIN 10 +Color: 1C Black"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GT-AL003T' '2A-METAL TANK GREY'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GT-AL007T' 'METAL TANK GREY'
#   "i7-9750H +GTX 1650-4GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GT-BQ006T' 'METAL TANK GREY'
#   "i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DD-AU055T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['NO' 'ROG-Strix G' 'G531GT-AL017T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['NO' 'ROG-Strix G' 'G531GT-AL018T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['NO' 'ROG-Strix G' 'G531GD-BQ036T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1050-4GB +8GB +1TB SSHD(FireCuda) +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DV-AL026T' 'GUN METAL'
#   "R7-3750H +RTX2060-6GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['NO' 'ROG-Strix G' 'G531GT-BQ024T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DY-AU072T' '1B-BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['NO' 'ROG-Strix G' 'G531GT-BQ124T' 'BLACK W+LIGHTBAR+'
#   'i5-9300H+ GTX1650+ 8G+ 1T SSD+ 15.6 FHD-60hz+ + BLACK W+LIGHTBAR+'
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DT-AU028T' 'BLACK PLASTIC'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar III' 'G531GU-ES016T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G531GU-ES511T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +RGB backlit keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar III' 'G531GV-AZ289T' '1A-SCAR Gunmetal'
#   "i7-9750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-G' 'G703GXR-EV078R' 'Aluminum'
#   "i9-9980HK +RTX2080-8GB +32GB +1TB SSHD(FireCuda)+512GB PCIE SSD*3 +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB +WIN 10 Pro +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET +Color: Aluminum\nTitanium with hairline"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-AU022T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7114T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7123T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DV-AL136T' 'GUN METAL'
#   "R7-3750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7147T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus S' 'GX701GXR-H6086T' 'BLACK METAL'
#   "i7-9750H +RTX2080 with Max-Q Design-8GB +32GB +1TB PCIE SSD +17.3'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam +Color: 1A-BLACK M"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7158T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-G' 'G703GI-E5148T' 'TITANIUM'
#   '17.3FHD IPS+G sync+144hz+I9-8950HK+64GB+2TB+3x 512GBPCIE gen3x4 SSD+GTX1080+8GBDDR5+1A-TITANIUM+n+a+WIN10+802.11ac+BT4.0+BAG MOUSE HEADSET+2Y'
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX504GM-E4112T' 'BLACK METAL'
#   "i5-8300H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+128GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX504GM-E4392T' 'BLACK METAL'
#   "i5-8300H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus' 'GX501GI-EI004T' 'BLACK METAL'
#   "i7-8750H +GTX1080-8GB +24GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-BLACK METAL"
#   '2Y']
#  ['Platinum' 'ROG-Zephyrus S' 'GX701GXR-EV025T' 'BLACK METAL'
#   "i7-9750H +RTX2080 with Max-Q Design-8GB +32GB +1TB PCIE SSD +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam +Color: 1A-BLACK M"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus S' 'GX531GW-ES009T' 'BLACK METAL'
#   "i7-8750H +RTX2070 with Max-Q Design-8GB +16GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-BLACK METAL"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar II' 'GL504GW-ES007T' 'Gunmatel'
#   "i7-8750H +RTX2070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-Gunmatel"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7159T' 'GLACIER BLUE W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G GLACIER BLUE W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar III' 'G531GW-AZ113T' 'SCAR Gunmetal'
#   "i9-9880H +RTX2070-8GB +32GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus M' 'GM501GS-EI004T' 'Black Metal'
#   "i7-8750H +GTX1070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: Black Metal"
#   '2Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7160T' 'GLACIER BLUE W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G GLACIER BLUE W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar II' 'GL504GS-ES113T' 'Gunmatel'
#   "i7-8750H +GTX1070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-Gunmatel"
#   '2Y']
#  ['Platinum' 'ROG-Strix Scar III' 'G531GW-AZ014T' 'SCAR Gunmetal'
#   "i7-9750H +RTX2070-8GB +16GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar II' 'GL504GV-ES019T' 'SCAR Gunmatel'
#   "i7-8750H +RTX2060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-SCAR Gunmatel"
#   '1Y']
#  ['Platinum' 'ROG-Strix Hero II' 'GL504GV-ES034T' 'HERO Black'
#   "i7-8750H +RTX2060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1B-HERO Black"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus M' 'GM501GM-EI005T' 'Black Metal'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: Black Metal"
#   '2Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7179T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +8GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix Hero II' 'GL504GM-ES152T' 'HERO Black'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1B-HERO Black"
#   '2Y']
#  ['Platinum' 'ROG-Strix Scar II' 'GL504GM-ES155T' 'SCAR Gunmatel'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-SCAR Gunmatel"
#   '2Y']
#  ['Platinum' 'ROG-Strix Scar III' 'G531GV-ES014T' 'SCAR Gunmetal'
#   "i7-9750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar III' 'G531GU-ES104T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-Strix Hero III' 'G531GU-ES133T' 'HERO Black'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1B-HERO Black"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DD-AU060T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['Platinum' 'ROG-Strix Scar III' 'G531GU-ES108T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +8GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G531GU-ES514T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +RGB backlit keyboard (1-Zone)+WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GM-ES065T' 'GUN METAL'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705GM-EV024T' 'Gunmetal'
#   "i7-8750H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+144Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: Gunmetal"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus G' 'GA502DU-AL055T' 'Black Metal'
#   "R7-3750H +GTX 1660Ti Max-Q-6GB +16GB +1TB PCIE SSD +15.6'+120Hz+Backlit Keyboard +WIN 10 +Color: Black Metal"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G531GD-BQ026T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1050-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-H7180T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX504GM-EN394T' 'BLACK METAL'
#   "i7-8750H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+120Hz+3ms +Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  ['Platinum' 'ROG-Strix G' 'G731GT-AU016T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GE-BQ030T' 'GUN METAL'
#   "i7-8750H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus G' 'GA502DU-AL025T' 'Black Metal'
#   "R7-3750H +GTX 1660Ti Max-Q-6GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: Black Metal"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus M' 'GU502GU-ES003T' 'Black metal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB +WIN 10 +Color: Black metal"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DT-AU096T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +16GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DT-AU020T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DT-AL033T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GE-BQ025T' 'GUN METAL'
#   "i5-8300H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus S' 'GX531GWR-AZ044T'
#   'Aluminum with plastic bone, Black with'
#   "i7-9750H +RTX2070 with Max-Q Design-8GB +24GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: Aluminum with plastic bone, Black with hairline"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus S' 'GX531GWR-ES024T'
#   'Aluminum with plastic bone, Black with'
#   "i7-9750H +RTX2070 with Max-Q Design-8GB +24GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: Aluminum with plastic bone, Black with hairline"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus S' 'GX701GX-EV058T' 'BLACK METAL'
#   "i7-8750H +RTX2080 with Max-Q Design-8GB +24GB +1TB PCIE SSD +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Bag+Mouse+Headset in box +Color: 1A-BLACK METAL"
#   '1Y']
#  ['Platinum' 'ROG-Zephyrus S' 'GX701GXR-HG113T' 'BLACK METAL'
#   'i7-9750H+ RTX2080 Max-Q+ 32GB+ 1TB PCIE SSD+ 17.3 FHD + 300Hz-3ms+ + Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam'
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX504GE-E4366T' 'BLACK METAL'
#   "i5-8300H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+128GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DT-AL003T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DT-AL059T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GM-BQ415T' '1A-GUN METAL'
#   "i5-8300H +GTX1060-6GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DT-AL189T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DT-AL162T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DT-AU094T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GD-BQ316T' 'GUN METAL'
#   "i5-8300H +GTX 1050-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505DD-AL199T' 'GUN METAL'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX705DY-AU027T' 'BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  ['Premium' 'VivoBook Gaming' 'F560UD-BQ237T' 'BLACK'
#   '15.6"FHD IPS+I5-8250U+8GB+1TB Firecuda+GTX1050+4GB+1C-BLACK METAL+No ODD+WIN10+802.11ac+BT 4.0++1Y'
#   '1Y']
#  ['Premium' 'VivoBook Gaming' 'F560UD-BQ335T' 'BLACK'
#   'i5-8250U +GTX 1050-4GB +8GB +1TB SSHD(FireCuda) +15.6 FHD USLIM WV,250NITS,NTSC:45%-NB +Chiclet Keyboard +WIN 10 +Color: 1B-BLACK-PLASTIC'
#   '1Y']
#  ['Premium' 'TUF Gaming' 'FX505GD-BQ136T' 'BLACK PATTERN PLASTIC'
#   "i5-8300H +GTX 1050-4GB +8GB +1TB HDD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK PATTERN PLASTIC"
#   '1Y']
#  ['Premium' 'VivoBook Gaming' 'F570ZD-DM226T' 'BLACK'
#   'R5-2500U +GTX 1050-4GB +8GB +1TB HDD +15.6 FHD +ILLUMINATED CHICLET +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1B-BLACK-PLASTIC'
#   '1Y']
#  ['Premium' 'TUF A15' 'FA566IH-HN145T' 'Fortress Gray'
#   'R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  ['Premium' 'TUF A15' 'FA566IH-HN150TS' 'Fortress Gray'
#   'R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+256G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+ MS office+'
#   '1Y']
#  ['Premium' 'TUF A15' 'FA566II-HN230T' 'Fortress Gray'
#   'R5-4600H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  ['Premium' 'TUF A15' 'FA566II-HN231T' 'Fortress Gray'
#   'R7-4800H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  ['Premium' 'TUF A15' 'FA566IU-HN244T' 'Fortress Gray'
#   'R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  ['Premium' 'TUF A15' 'FA566IU-HN246T' 'Fortress Gray'
#   'R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']]

# %%
print(y)
# Out:
# [ 77990  80990  94990  97990  98990  67990  79990  90990 109990  89990
#   72990 110990 116990  77990 123990 100990  71990 101990  90990 188990
#  142990 201990 519990 103990 111990 118990 136990 101990 396990 129990
#  649990 106990  90990 389990 389990 311990 272990 127990 324990 259990
#  101990 240990 259990 214990 214990 214990 118990 185990 185990 201990
#  181990 181990  76990 168990 149990 136990 133990 123990  84990 106990
#  114990 110990 102990 129990 185990 103990  94990  90990  87990 322990
#  311990 454990 402990  85990  88990  84990  80990  80990  75990  77990
#   81990  75990  72990  71990  64990  67990  66990  94990  96990  98990
#  110990 120990 128990]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL118T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU092T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU016T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GT-BQ002T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GT-AL264T'
#   '1F-G Glacier Blue W+ Lightbar'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G Glacier Blue W+ Lightbar"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DY-BQ024T' 'BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GM-BQ344T' '1C Black'
#   "I5-8300H +GTX1060-6GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard- Red +WIN 10 +Color: 1C Black"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GT-AL003T' '2A-METAL TANK GREY'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GT-AL007T' 'METAL TANK GREY'
#   "i7-9750H +GTX 1650-4GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GT-BQ006T' 'METAL TANK GREY'
#   "i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DD-AU055T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-AL017T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-AL018T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GD-BQ036T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1050-4GB +8GB +1TB SSHD(FireCuda) +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DV-AL026T' 'GUN METAL'
#   "R7-3750H +RTX2060-6GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-BQ024T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DY-AU072T' '1B-BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-BQ124T' 'BLACK W+LIGHTBAR+'
#   'i5-9300H+ GTX1650+ 8G+ 1T SSD+ 15.6 FHD-60hz+ + BLACK W+LIGHTBAR+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU028T' 'BLACK PLASTIC'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GU-ES016T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GU-ES511T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +RGB backlit keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GV-AZ289T' '1A-SCAR Gunmetal'
#   "i7-9750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-G' 'G703GXR-EV078R' 'Aluminum'
#   "i9-9980HK +RTX2080-8GB +32GB +1TB SSHD(FireCuda)+512GB PCIE SSD*3 +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB +WIN 10 Pro +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET +Color: Aluminum\nTitanium with hairline"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-AU022T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7114T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7123T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DV-AL136T' 'GUN METAL'
#   "R7-3750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7147T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GXR-H6086T' 'BLACK METAL'
#   "i7-9750H +RTX2080 with Max-Q Design-8GB +32GB +1TB PCIE SSD +17.3'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam +Color: 1A-BLACK M"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7158T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-G' 'G703GI-E5148T' 'TITANIUM'
#   '17.3FHD IPS+G sync+144hz+I9-8950HK+64GB+2TB+3x 512GBPCIE gen3x4 SSD+GTX1080+8GBDDR5+1A-TITANIUM+n+a+WIN10+802.11ac+BT4.0+BAG MOUSE HEADSET+2Y'
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX504GM-E4112T' 'BLACK METAL'
#   "i5-8300H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+128GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX504GM-E4392T' 'BLACK METAL'
#   "i5-8300H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus' 'GX501GI-EI004T' 'BLACK METAL'
#   "i7-8750H +GTX1080-8GB +24GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-BLACK METAL"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GXR-EV025T' 'BLACK METAL'
#   "i7-9750H +RTX2080 with Max-Q Design-8GB +32GB +1TB PCIE SSD +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam +Color: 1A-BLACK M"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX531GW-ES009T' 'BLACK METAL'
#   "i7-8750H +RTX2070 with Max-Q Design-8GB +16GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-BLACK METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GW-ES007T' 'Gunmatel'
#   "i7-8750H +RTX2070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-Gunmatel"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7159T' 'GLACIER BLUE W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G GLACIER BLUE W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GW-AZ113T' 'SCAR Gunmetal'
#   "i9-9880H +RTX2070-8GB +32GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus M' 'GM501GS-EI004T' 'Black Metal'
#   "i7-8750H +GTX1070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: Black Metal"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7160T' 'GLACIER BLUE W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G GLACIER BLUE W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GS-ES113T' 'Gunmatel'
#   "i7-8750H +GTX1070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-Gunmatel"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GW-AZ014T' 'SCAR Gunmetal'
#   "i7-9750H +RTX2070-8GB +16GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GV-ES019T' 'SCAR Gunmatel'
#   "i7-8750H +RTX2060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-SCAR Gunmatel"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Hero II' 'GL504GV-ES034T' 'HERO Black'
#   "i7-8750H +RTX2060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1B-HERO Black"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus M' 'GM501GM-EI005T' 'Black Metal'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: Black Metal"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7179T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +8GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Hero II' 'GL504GM-ES152T' 'HERO Black'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1B-HERO Black"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GM-ES155T' 'SCAR Gunmatel'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-SCAR Gunmatel"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GV-ES014T' 'SCAR Gunmetal'
#   "i7-9750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GU-ES104T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Hero III' 'G531GU-ES133T' 'HERO Black'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1B-HERO Black"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DD-AU060T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GU-ES108T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +8GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GU-ES514T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +RGB backlit keyboard (1-Zone)+WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GM-ES065T' 'GUN METAL'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705GM-EV024T' 'Gunmetal'
#   "i7-8750H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+144Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus G' 'GA502DU-AL055T' 'Black Metal'
#   "R7-3750H +GTX 1660Ti Max-Q-6GB +16GB +1TB PCIE SSD +15.6'+120Hz+Backlit Keyboard +WIN 10 +Color: Black Metal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GD-BQ026T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1050-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7180T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX504GM-EN394T' 'BLACK METAL'
#   "i7-8750H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+120Hz+3ms +Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-AU016T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GE-BQ030T' 'GUN METAL'
#   "i7-8750H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus G' 'GA502DU-AL025T' 'Black Metal'
#   "R7-3750H +GTX 1660Ti Max-Q-6GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: Black Metal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus M' 'GU502GU-ES003T' 'Black metal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB +WIN 10 +Color: Black metal"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU096T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +16GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU020T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL033T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GE-BQ025T' 'GUN METAL'
#   "i5-8300H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX531GWR-AZ044T'
#   'Aluminum with plastic bone, Black with'
#   "i7-9750H +RTX2070 with Max-Q Design-8GB +24GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: Aluminum with plastic bone, Black with hairline"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX531GWR-ES024T'
#   'Aluminum with plastic bone, Black with'
#   "i7-9750H +RTX2070 with Max-Q Design-8GB +24GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: Aluminum with plastic bone, Black with hairline"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GX-EV058T' 'BLACK METAL'
#   "i7-8750H +RTX2080 with Max-Q Design-8GB +24GB +1TB PCIE SSD +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Bag+Mouse+Headset in box +Color: 1A-BLACK METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GXR-HG113T' 'BLACK METAL'
#   'i7-9750H+ RTX2080 Max-Q+ 32GB+ 1TB PCIE SSD+ 17.3 FHD + 300Hz-3ms+ + Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam'
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX504GE-E4366T' 'BLACK METAL'
#   "i5-8300H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+128GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL003T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL059T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GM-BQ415T' '1A-GUN METAL'
#   "i5-8300H +GTX1060-6GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL189T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL162T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU094T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GD-BQ316T' 'GUN METAL'
#   "i5-8300H +GTX 1050-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DD-AL199T' 'GUN METAL'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DY-AU027T' 'BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'VivoBook Gaming' 'F560UD-BQ237T' 'BLACK'
#   '15.6"FHD IPS+I5-8250U+8GB+1TB Firecuda+GTX1050+4GB+1C-BLACK METAL+No ODD+WIN10+802.11ac+BT 4.0++1Y'
#   '1Y']
#  [0.0 0.0 1.0 'VivoBook Gaming' 'F560UD-BQ335T' 'BLACK'
#   'i5-8250U +GTX 1050-4GB +8GB +1TB SSHD(FireCuda) +15.6 FHD USLIM WV,250NITS,NTSC:45%-NB +Chiclet Keyboard +WIN 10 +Color: 1B-BLACK-PLASTIC'
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GD-BQ136T' 'BLACK PATTERN PLASTIC'
#   "i5-8300H +GTX 1050-4GB +8GB +1TB HDD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK PATTERN PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'VivoBook Gaming' 'F570ZD-DM226T' 'BLACK'
#   'R5-2500U +GTX 1050-4GB +8GB +1TB HDD +15.6 FHD +ILLUMINATED CHICLET +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1B-BLACK-PLASTIC'
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IH-HN145T' 'Fortress Gray'
#   'R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IH-HN150TS' 'Fortress Gray'
#   'R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+256G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+ MS office+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566II-HN230T' 'Fortress Gray'
#   'R5-4600H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566II-HN231T' 'Fortress Gray'
#   'R7-4800H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IU-HN244T' 'Fortress Gray'
#   'R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IU-HN246T' 'Fortress Gray'
#   'R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        93 non-null     object
#  1   Series          93 non-null     object
#  2   ModelName       93 non-null     object
#  3   Colour&Chassis  93 non-null     object
#  4   Description     93 non-null     object
#  5   Warrenty        93 non-null     object
#  6   MRP             93 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 5.2+ KB

# %%
dataset
# Out:
#     Category       Series        ModelName                 Colour&Chassis  \
# 0    Premium   TUF Gaming   FX505DT-AL118T                      GUN METAL
# 1    Premium   TUF Gaming   FX705DT-AU092T                  BLACK PLASTIC
# 2    Premium   TUF Gaming   FX705DT-AU016T                      GUN METAL
# 3   Platinum  ROG-Strix G    G531GT-BQ002T               BLACK W+LIGHTBAR
# 4   Platinum  ROG-Strix G    G531GT-AL264T  1F-G Glacier Blue W+ Lightbar
# ..       ...          ...              ...                            ...
# 88   Premium      TUF A15  FA566IH-HN150TS                  Fortress Gray
# 89   Premium      TUF A15   FA566II-HN230T                  Fortress Gray
# 90   Premium      TUF A15   FA566II-HN231T                  Fortress Gray
# 91   Premium      TUF A15   FA566IU-HN244T                  Fortress Gray
# 92   Premium      TUF A15   FA566IU-HN246T                  Fortress Gray
#
#                                           Description Warrenty     MRP
# 0   R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   77990
# 1   R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   80990
# 2   R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   94990
# 3   i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +1...       1Y   97990
# 4   i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15...       1Y   98990
# ..                                                ...      ...     ...
# 88  R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+256G SSD+ ...       1Y   96990
# 89  R5-4600H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD...       1Y   98990
# 90  R7-4800H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD...       1Y  110990
# 91  R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T HDD+512G ...       1Y  120990
# 92  R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T SSD+ 15.6...       1Y  128990
#
# [93 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(y)
# Out:
# [ 7  9 17 19 20  2  8 16 26 15  4 27 30  7 33 21  3 22 16 44 39 45 57 24
#  28 31 38 22 54 36 58 25 16 53 53 50 49 34 52 48 22 47 48 46 46 46 31 43
#  43 45 42 42  6 41 40 38 37 33 11 25 29 27 23 36 43 24 17 16 13 51 50 56
#  55 12 14 11  9  9  5  7 10  5  4  3  0  2  1 17 18 20 27 32 35]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
print(X_train)
# Out:
# [[0.0 0.0 1.0 'TUF Gaming' 'FX504GE-E4366T' 'BLACK METAL'
#   "i5-8300H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+128GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GM-ES155T' 'SCAR Gunmatel'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-SCAR Gunmatel"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GU-ES016T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IH-HN145T' 'Fortress Gray'
#   'R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GW-ES007T' 'Gunmatel'
#   "i7-8750H +RTX2070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-Gunmatel"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus' 'GX501GI-EI004T' 'BLACK METAL'
#   "i7-8750H +GTX1080-8GB +24GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-BLACK METAL"
#   '2Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX504GM-E4392T' 'BLACK METAL'
#   "i5-8300H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7179T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +8GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX531GWR-ES024T'
#   'Aluminum with plastic bone, Black with'
#   "i7-9750H +RTX2070 with Max-Q Design-8GB +24GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: Aluminum with plastic bone, Black with hairline"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GD-BQ136T' 'BLACK PATTERN PLASTIC'
#   "i5-8300H +GTX 1050-4GB +8GB +1TB HDD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK PATTERN PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DD-AU060T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX531GW-ES009T' 'BLACK METAL'
#   "i7-8750H +RTX2070 with Max-Q Design-8GB +16GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-BLACK METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GS-ES113T' 'Gunmatel'
#   "i7-8750H +GTX1070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-Gunmatel"
#   '2Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DD-AL199T' 'GUN METAL'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-AU022T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GXR-EV025T' 'BLACK METAL'
#   "i7-9750H +RTX2080 with Max-Q Design-8GB +32GB +1TB PCIE SSD +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam +Color: 1A-BLACK M"
#   '1Y']
#  [0.0 0.0 1.0 'VivoBook Gaming' 'F570ZD-DM226T' 'BLACK'
#   'R5-2500U +GTX 1050-4GB +8GB +1TB HDD +15.6 FHD +ILLUMINATED CHICLET +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1B-BLACK-PLASTIC'
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus M' 'GM501GM-EI005T' 'Black Metal'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: Black Metal"
#   '2Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU096T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +16GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-BQ024T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DY-AU027T' 'BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'VivoBook Gaming' 'F560UD-BQ335T' 'BLACK'
#   'i5-8250U +GTX 1050-4GB +8GB +1TB SSHD(FireCuda) +15.6 FHD USLIM WV,250NITS,NTSC:45%-NB +Chiclet Keyboard +WIN 10 +Color: 1B-BLACK-PLASTIC'
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DV-AL136T' 'GUN METAL'
#   "R7-3750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IU-HN244T' 'Fortress Gray'
#   'R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar II' 'GL504GV-ES019T' 'SCAR Gunmatel'
#   "i7-8750H +RTX2060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1A-SCAR Gunmatel"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU020T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GT-AL264T'
#   '1F-G Glacier Blue W+ Lightbar'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G Glacier Blue W+ Lightbar"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GV-ES014T' 'SCAR Gunmetal'
#   "i7-9750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GV-AZ289T' '1A-SCAR Gunmetal'
#   "i7-9750H +RTX2060-6GB +16GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GD-BQ316T' 'GUN METAL'
#   "i5-8300H +GTX 1050-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GT-BQ002T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL033T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-G' 'G703GI-E5148T' 'TITANIUM'
#   '17.3FHD IPS+G sync+144hz+I9-8950HK+64GB+2TB+3x 512GBPCIE gen3x4 SSD+GTX1080+8GBDDR5+1A-TITANIUM+n+a+WIN10+802.11ac+BT4.0+BAG MOUSE HEADSET+2Y'
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GD-BQ026T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1050-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GW-AZ014T' 'SCAR Gunmetal'
#   "i7-9750H +RTX2070-8GB +16GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Hero II' 'GL504GM-ES152T' 'HERO Black'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1B-HERO Black"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix Hero III' 'G531GU-ES133T' 'HERO Black'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1B-HERO Black"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX531GWR-AZ044T'
#   'Aluminum with plastic bone, Black with'
#   "i7-9750H +RTX2070 with Max-Q Design-8GB +24GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: Aluminum with plastic bone, Black with hairline"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7114T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GT-AL007T' 'METAL TANK GREY'
#   "i7-9750H +GTX 1650-4GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-BQ124T' 'BLACK W+LIGHTBAR+'
#   'i5-9300H+ GTX1650+ 8G+ 1T SSD+ 15.6 FHD-60hz+ + BLACK W+LIGHTBAR+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX504GM-EN394T' 'BLACK METAL'
#   "i7-8750H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+120Hz+3ms +Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL118T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'VivoBook Gaming' 'F560UD-BQ237T' 'BLACK'
#   '15.6"FHD IPS+I5-8250U+8GB+1TB Firecuda+GTX1050+4GB+1C-BLACK METAL+No ODD+WIN10+802.11ac+BT 4.0++1Y'
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus G' 'GA502DU-AL055T' 'Black Metal'
#   "R7-3750H +GTX 1660Ti Max-Q-6GB +16GB +1TB PCIE SSD +15.6'+120Hz+Backlit Keyboard +WIN 10 +Color: Black Metal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-G' 'G703GXR-EV078R' 'Aluminum'
#   "i9-9980HK +RTX2080-8GB +32GB +1TB SSHD(FireCuda)+512GB PCIE SSD*3 +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB +WIN 10 Pro +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET +Color: Aluminum\nTitanium with hairline"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-AU016T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus G' 'GA502DU-AL025T' 'Black Metal'
#   "R7-3750H +GTX 1660Ti Max-Q-6GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: Black Metal"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GT-AL003T' '2A-METAL TANK GREY'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566II-HN230T' 'Fortress Gray'
#   'R5-4600H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GD-BQ036T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1050-4GB +8GB +1TB SSHD(FireCuda) +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GE-BQ025T' 'GUN METAL'
#   "i5-8300H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL162T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DV-AL026T' 'GUN METAL'
#   "R7-3750H +RTX2060-6GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7158T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GXR-H6086T' 'BLACK METAL'
#   "i7-9750H +RTX2080 with Max-Q Design-8GB +32GB +1TB PCIE SSD +17.3'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam +Color: 1A-BLACK M"
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-AL017T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU028T' 'BLACK PLASTIC'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GU-ES511T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +RGB backlit keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GU-ES104T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7123T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GM-BQ344T' '1C Black'
#   "I5-8300H +GTX1060-6GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard- Red +WIN 10 +Color: 1C Black"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GX-EV058T' 'BLACK METAL'
#   "i7-8750H +RTX2080 with Max-Q Design-8GB +24GB +1TB PCIE SSD +17.3'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Bag+Mouse+Headset in box +Color: 1A-BLACK METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GM-BQ415T' '1A-GUN METAL'
#   "i5-8300H +GTX1060-6GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU092T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DY-AU072T' '1B-BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus M' 'GU502GU-ES003T' 'Black metal'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB +WIN 10 +Color: Black metal"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU094T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DY-BQ024T' 'BLACK PLASTIC'
#   "R5-3550H +RX560X-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL059T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +1TB HDD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GT-BQ006T' 'METAL TANK GREY'
#   "i5-9300H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 2A-METAL TANK GREY"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus S' 'GX701GXR-HG113T' 'BLACK METAL'
#   'i7-9750H+ RTX2080 Max-Q+ 32GB+ 1TB PCIE SSD+ 17.3 FHD + 300Hz-3ms+ + Accy in box: Bag, MOUSE(GLADIUS2), HEADSET, Web Cam'
#   '1Y']
#  [1.0 0.0 0.0 'ROG-Strix G' 'G531GT-AL018T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1650-4GB +16GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7159T' 'GLACIER BLUE W+LIGHTBAR'
#   "i7-9750H +GTX1650-4GB +16GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G GLACIER BLUE W+LIGHTBAR"
#   '1Y']]

# %%
print(X_test)
# Out:
# [[0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7180T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +1TB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL003T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Hero II' 'GL504GV-ES034T' 'HERO Black'
#   "i7-8750H +RTX2060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: 1B-HERO Black"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705GM-EV024T' 'Gunmetal'
#   "i7-8750H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +17.3'+144Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: Gunmetal"
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IH-HN150TS' 'Fortress Gray'
#   'R5-4600H+ GTX1650 (6GB)+ 8G+ 1T HDD+256G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+ MS office+'
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505DT-AL189T' 'GUN METAL'
#   "R5-3550H +GTX 1650-4GB +8GB +1TB HDD+256GB PCIE SSD +15.6'+120Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GE-BQ030T' 'GUN METAL'
#   "i7-8750H +GTX 1050 Ti-4GB +8GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GU-ES108T' 'SCAR Gunmetal'
#   "i7-9750H +GTX 1660Ti-6GB +8GB +512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G531GU-ES514T' 'BLACK W+LIGHTBAR'
#   "i7-9750H +GTX 1660Ti-6GB +16GB +1TB PCIE SSD +15.6'+144Hz+3ms +RGB backlit keyboard (1-Zone)+WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Zephyrus M' 'GM501GS-EI004T' 'Black Metal'
#   "i7-8750H +GTX1070-8GB +16GB +1TB SSHD(FireCuda)+512GB PCIE SSD +15.6'+144Hz+3ms +Illuminated Chiclet Keyboard 4-Zone RGB +WIN 10 +Color: Black Metal"
#   '2Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7160T' 'GLACIER BLUE W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIN 10 +Color: 1F-G GLACIER BLUE W+LIGHTBAR"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX504GM-E4112T' 'BLACK METAL'
#   "i5-8300H +GTX1060-6GB +8GB +1TB SSHD(FireCuda)+128GB PCIE SSD +15.6'+60Hz+Illuminated Chiclet Keyboard +WIN 10 +Color: 1C-BLACK METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566II-HN231T' 'Fortress Gray'
#   'R7-4800H+ GTX1650Ti (6GB)+ 8G+ 1T HDD+512G SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix G' 'G731GT-H7147T' 'BLACK W+LIGHTBAR'
#   "i5-9300H +GTX1650-4GB +8GB +512GB PCIE SSD +17.3'+120Hz+16ms +RGB backlit Keyboard (1-Zone) +WIFI5(802.11AC)2*2 +WIN 10 +Color: 1C-G BLACK W+LIGHTBAR"
#   '1Y']
#  [0.0 1.0 0.0 'ROG-Strix Scar III' 'G531GW-AZ113T' 'SCAR Gunmetal'
#   "i9-9880H +RTX2070-8GB +32GB +1TB PCIE SSD +15.6'+240Hz+3ms +Illuminated Chiclet Keyboard Per-Key RGB+NumberPad +WIN 10 +Color: 1A-SCAR Gunmetal"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX505GM-ES065T' 'GUN METAL'
#   "i7-8750H +GTX1060-6GB +16GB +1TB SSHD(FireCuda)+256GB PCIE SSD +15.6'+144Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DD-AU055T' 'BLACK PLASTIC'
#   "R5-3550H +GTX 1050-3GB +8GB +1TB HDD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1B-BLACK PLASTIC"
#   '1Y']
#  [0.0 0.0 1.0 'TUF Gaming' 'FX705DT-AU016T' 'GUN METAL'
#   "R7-3750H +GTX 1650-4GB +8GB +512GB PCIE SSD +17.3'+60Hz+Illuminated Chiclet Keyboard RGB +WIN 10 +Color: 1A-GUN METAL"
#   '1Y']
#  [0.0 0.0 1.0 'TUF A15' 'FA566IU-HN246T' 'Fortress Gray'
#   'R7-4800H+ GTX1660Ti (6GB)+ 8G+8G+ 1T SSD+ 15.6 FHD-144hz+ 48Wh+ Fortress Gray+'
#   '1Y']]

# %%
print(y_train)
# Out:
# [12 43 44 17 49 53 16 31 50  2  6 50 47  5 24 53  1 46 24 21  4  0 38 32
#  46 17 20 45 45 10 19 16 58 11 48 43 42 51 28 26 22 29  7  3 33 57 27 36
#  16 20  7 13  5 33 36 54 27 16 39 42 31  8 56  9  9  3 43  7  2 11 15 55
#  30 34]

# %%
print(y_test)
# Out:
# [25 14 46 37 18  9 23 41 40 48 22 25 27 22 52 38  4 17 35]
